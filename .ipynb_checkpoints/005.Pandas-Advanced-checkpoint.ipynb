# %% [markdown]
# # 005. Advanced Pandas

# %% [markdown]
# ### csv file handling

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/winequality-red.csv", sep=";")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### DataFrame 을 csv file 로 write

# %%
df2 = df.loc[:, ['quality', 'alcohol', 'pH']]
df2.to_csv('data/winequality-2.csv')

# %%
pd.read_csv('data/winequality-2.csv', index_col=0).head()
# Out:
#    quality  alcohol    pH
# 0        5      9.4  3.51
# 1        5      9.8  3.20
# 2        5      9.8  3.26
# 3        6      9.8  3.16
# 4        5      9.4  3.51

# %% [markdown]
# ### df.apply + lambda

# %%
df["New_val"] = df.apply(lambda x : x["fixed acidity"] + x["citric acid"] , axis = 1 )
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  New_val
# 0      9.4        5     7.40
# 1      9.8        5     7.80
# 2      9.8        5     7.84
# 3      9.8        6    11.76
# 4      9.4        5     7.40

# %% [markdown]
# ### lambda 보다 더 복잡한 함수 적용

# %%
def custom(alcohol , ph) :
    if alcohol < 10 :
        return ph * 1.5
    else :
        return ph * -1

df["New_pH"] = df.apply(lambda x : custom(x["alcohol"], x["pH"]) , axis = 1 )
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  New_val  New_pH
# 0      9.4        5     7.40   5.265
# 1      9.8        5     7.80   4.800
# 2      9.8        5     7.84   4.890
# 3      9.8        6    11.76   4.740
# 4      9.4        5     7.40   5.265

# %% [markdown]
# ## Boolean mask condition 으로 DataFrame 검색

# %%
df = pd.read_csv("data/olympics.csv", index_col=0, skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# Afghanistan (AFG)             2               2
# Algeria (ALG)                 8              15
# Argentina (ARG)              28              70
# Armenia (ARM)                 9              12
# Australasia (ANZ) [ANZ]       5              12

# %% [markdown]
# ### column 명 변경

# %%
import re

columns = [re.sub('№', '#', col) for col in df. columns]
columns = [re.sub('[! ]', '', col) for col in columns]
columns = [re.sub('01', 'Gold', col) for col in columns]
columns = [re.sub('02', 'Silver', col) for col in columns]
columns = [re.sub('03', 'Bronze', col) for col in columns]
columns
# Out:
# ['#Summer',
#  'Gold',
#  'Silver',
#  'Bronze',
#  'Total',
#  '#Winter',
#  'Gold.1',
#  'Silver.1',
#  'Bronze.1',
#  'Total.1',
#  '#Games',
#  'Gold.2',
#  'Silver.2',
#  'Bronze.2',
#  'Combinedtotal']

# %%
df.columns = columns
df.head()
# Out:
#                          #Summer  Gold  Silver  Bronze  Total  #Winter  \
# Afghanistan (AFG)             13     0       0       2      2        0
# Algeria (ALG)                 12     5       2       8     15        3
# Argentina (ARG)               23    18      24      28     70       18
# Armenia (ARM)                  5     1       2       9     12        6
# Australasia (ANZ) [ANZ]        2     3       4       5     12        0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  #Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0      13       0
# Algeria (ALG)                 0         0         0        0      15       5
# Argentina (ARG)               0         0         0        0      41      18
# Armenia (ARM)                 0         0         0        0      11       1
# Australasia (ANZ) [ANZ]       0         0         0        0       2       3
#
#                          Silver.2  Bronze.2  Combinedtotal
# Afghanistan (AFG)               0         2              2
# Algeria (ALG)                   2         8             15
# Argentina (ARG)                24        28             70
# Armenia (ARM)                   2         9             12
# Australasia (ANZ) [ANZ]         4         5             12

# %%
# 하계올림픽 금메달 1 개 이상 얻은 나라
df['Gold'] > 0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
#                                                 ...
# Independent Olympic Participants (IOP) [IOP]    False
# Zambia (ZAM) [ZAM]                              False
# Zimbabwe (ZIM) [ZIM]                             True
# Mixed team (ZZX) [ZZX]                           True
# Totals                                           True
# Name: Gold, Length: 147, dtype: bool

# %% [markdown]
# ### Boolean indexing
#
# - where : no value 포함하여 return
#
# - boolean indexing : no value 제외 return

# %%
only_gold = df.where(df['Gold'] > 0)

print(only_gold.shape)
only_gold.head()
# Out:
# (147, 15)
#                          #Summer  Gold  Silver  Bronze  Total  #Winter  \
# Afghanistan (AFG)            NaN   NaN     NaN     NaN    NaN      NaN
# Algeria (ALG)               12.0   5.0     2.0     8.0   15.0      3.0
# Argentina (ARG)             23.0  18.0    24.0    28.0   70.0     18.0
# Armenia (ARM)                5.0   1.0     2.0     9.0   12.0      6.0
# Australasia (ANZ) [ANZ]      2.0   3.0     4.0     5.0   12.0      0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  #Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN     NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0    15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0    41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0    11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0     2.0     3.0
#
#                          Silver.2  Bronze.2  Combinedtotal
# Afghanistan (AFG)             NaN       NaN            NaN
# Algeria (ALG)                 2.0       8.0           15.0
# Argentina (ARG)              24.0      28.0           70.0
# Armenia (ARM)                 2.0       9.0           12.0
# Australasia (ANZ) [ANZ]       4.0       5.0           12.0

# %%
only_gold = df[df['Gold'] > 0]

print(only_gold.shape)
only_gold.head()
# Out:
# (100, 15)
#                            #Summer  Gold  Silver  Bronze  Total  #Winter  \
# Algeria (ALG)                   12     5       2       8     15        3
# Argentina (ARG)                 23    18      24      28     70       18
# Armenia (ARM)                    5     1       2       9     12        6
# Australasia (ANZ) [ANZ]          2     3       4       5     12        0
# Australia (AUS) [AUS] [Z]       25   139     152     177    468       18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  #Games  \
# Algeria (ALG)                   0         0         0        0      15
# Argentina (ARG)                 0         0         0        0      41
# Armenia (ARM)                   0         0         0        0      11
# Australasia (ANZ) [ANZ]         0         0         0        0       2
# Australia (AUS) [AUS] [Z]       5         3         4       12      43
#
#                            Gold.2  Silver.2  Bronze.2  Combinedtotal
# Algeria (ALG)                   5         2         8             15
# Argentina (ARG)                18        24        28             70
# Armenia (ARM)                   1         2         9             12
# Australasia (ANZ) [ANZ]         3         4         5             12
# Australia (AUS) [AUS] [Z]     144       155       181            480

# %%
# 하계올림픽 금메달 1 개 이상 또는 동계올림픽 금메달 1 개 이상인 국가의 숫자
len(df[(df['Gold'] > 0) | (df['Gold.1'] > 0)])
# Out:
# 101

# %%
# 하계올림픽 금메달은 없지만 동계올림픽 금메달 1 개 이상인 국가
df[(df['Gold'] == 0) & (df['Gold.1'] > 0)]
# Out:
#                      #Summer  Gold  Silver  Bronze  Total  #Winter  Gold.1  \
# Liechtenstein (LIE)       16     0       0       0      0       18       2
#
#                      Silver.1  Bronze.1  Total.1  #Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9      34       2         2
#
#                      Bronze.2  Combinedtotal
# Liechtenstein (LIE)         5              9

# %%
df2 = df.copy()

# %%
df2['country'] = df2.index
df2.set_index('Gold', inplace=True)
df2.sort_index(ascending=False, inplace=True)
df2.head()
# Out:
#       #Summer  Silver  Bronze  Total  #Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 4809       27    4775    5130  14714       22     959       958       948
# 976        26     757     666   2399       22      96       102        84
# 395         9     319     296   1010        9      78        57        59
# 236        27     272     272    780       22      10         4        12
# 202        27     223     246    671       22      31        31        47
#
#       Total.1  #Games  Gold.2  Silver.2  Bronze.2  Combinedtotal  \
# Gold
# 4809     2865      49    5768      5733      6078          17579
# 976       282      48    1072       859       750           2681
# 395       194      18     473       376       355           1204
# 236        26      49     246       276       284            806
# 202       109      49     233       254       293            780
#
#                                   country
# Gold
# 4809                               Totals
# 976   United States (USA) [P] [Q] [R] [Z]
# 395              Soviet Union (URS) [URS]
# 236         Great Britain (GBR) [GBR] [Z]
# 202              France (FRA) [O] [P] [Z]

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#                      index  #Summer  Gold  Silver  Bronze  Total  #Winter  \
# 0        Afghanistan (AFG)       13     0       0       2      2        0
# 1            Algeria (ALG)       12     5       2       8     15        3
# 2          Argentina (ARG)       23    18      24      28     70       18
# 3            Armenia (ARM)        5     1       2       9     12        6
# 4  Australasia (ANZ) [ANZ]        2     3       4       5     12        0
#
#    Gold.1  Silver.1  Bronze.1  Total.1  #Games  Gold.2  Silver.2  Bronze.2  \
# 0       0         0         0        0      13       0         0         2
# 1       0         0         0        0      15       5         2         8
# 2       0         0         0        0      41      18        24        28
# 3       0         0         0        0      11       1         2         9
# 4       0         0         0        0       2       3         4         5
#
#    Combinedtotal
# 0              2
# 1             15
# 2             70
# 3             12
# 4             12

# %% [markdown]
# ## multi-level index
#
# - country level, state level, county level 의 summary
#
# - STNAME : state name
# - CTYNAME : county name

# %%
df = pd.read_csv("data/census.csv")
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
#
# [5 rows x 100 columns]

# %% [markdown]
# - SUMLEV : 50 - county level, 40 - state level

# %%
df['SUMLEV'].value_counts()
# Out:
# 50    3142
# 40      51
# Name: SUMLEV, dtype: int64

# %%
columns_to_keep = ['STNAME', 'CTYNAME',
                   'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 
                   'BIRTHS2013', 'BIRTHS2014', 'BIRTHS2015']

# %%
df = df[columns_to_keep]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 0  Alabama         Alabama       14226       59689       59062       57938
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
#
#    BIRTHS2014  BIRTHS2015
# 0       58334       58305
# 1         623         600
# 2        2186        2240
# 3         260         269
# 4         247         253

# %%
df.columns
# Out:
# Index(['STNAME', 'CTYNAME', 'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012',
#        'BIRTHS2013', 'BIRTHS2014', 'BIRTHS2015'],
#       dtype='object')

# %% [markdown]
# - multi-level index 생성

# %%
df.set_index(['STNAME', 'CTYNAME'], inplace=True)
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama              14226       59689       59062       57938
#         Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#
#                         BIRTHS2014  BIRTHS2015
# STNAME  CTYNAME
# Alabama Alabama              58334       58305
#         Autauga County         623         600
#         Baldwin County        2186        2240
#         Barbour County         260         269
#         Bibb County            247         253

# %%
print(set([state for state, county in df.index.values]))
# Out:
# {'Mississippi', 'Maryland', 'North Dakota', 'Arizona', 'California', 'Illinois', 'Ohio', 'Oregon', 'Wyoming', 'Delaware', 'New Mexico', 'Louisiana', 'Idaho', 'Tennessee', 'Oklahoma', 'Florida', 'West Virginia', 'Nebraska', 'Connecticut', 'New Jersey', 'Massachusetts', 'Montana', 'Hawaii', 'Colorado', 'Georgia', 'Rhode Island', 'New Hampshire', 'Vermont', 'Pennsylvania', 'Alabama', 'Utah', 'Maine', 'Kentucky', 'Kansas', 'Nevada', 'Alaska', 'South Dakota', 'Michigan', 'Missouri', 'Wisconsin', 'District of Columbia', 'Minnesota', 'Texas', 'Arkansas', 'Indiana', 'North Carolina', 'South Carolina', 'Virginia', 'Washington', 'Iowa', 'New York'}

# %%
print(set([county for state, county in df.index.values if state == 'New York']))
# Out:
# {'Schoharie County', 'Niagara County', 'Herkimer County', 'Cortland County', 'Oneida County', 'Jefferson County', 'Wayne County', 'Nassau County', 'Schuyler County', 'Onondaga County', 'Seneca County', 'Allegany County', 'Madison County', 'Monroe County', 'Tioga County', 'Genesee County', 'Clinton County', 'Wyoming County', 'Washington County', 'Columbia County', 'Putnam County', 'Queens County', 'New York County', 'Tompkins County', 'Orleans County', 'Ontario County', 'Cattaraugus County', 'Livingston County', 'Westchester County', 'Albany County', 'Otsego County', 'Schenectady County', 'Rockland County', 'Steuben County', 'Greene County', 'Lewis County', 'Bronx County', 'Broome County', 'Orange County', 'Erie County', 'Warren County', 'Hamilton County', 'Ulster County', 'Chemung County', 'Yates County', 'Kings County', 'Richmond County', 'Fulton County', 'Rensselaer County', 'Franklin County', 'Cayuga County', 'Suffolk County', 'St. Lawrence County', 'Chenango County', 'Oswego County', 'Dutchess County', 'Essex County', 'Sullivan County', 'Chautauqua County', 'Saratoga County', 'Montgomery County', 'Delaware County', 'New York'}

# %% [markdown]
# - 특정 state, county 만 query

# %%
df.loc[[('New York', 'Albany County'), ('New York', 'Delaware County')]]
# Out:
#                           BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# New York Albany County           785        3092        3124        3195
#          Delaware County         121         468         400         407
#
#                           BIRTHS2014  BIRTHS2015
# STNAME   CTYNAME
# New York Albany County          3108        3100
#          Delaware County         368         366

# %% [markdown]
# ### 함수 apply
# - county 별 최대, 최소값을 계산하는 함수 작성
#
# - series 를 반환하는 경우와 row 를 반환하는 경우 비교

# %%
rows = df.columns.tolist()
rows
# Out:
# ['BIRTHS2010',
#  'BIRTHS2011',
#  'BIRTHS2012',
#  'BIRTHS2013',
#  'BIRTHS2014',
#  'BIRTHS2015']

# %% [markdown]
# - series 를 반환하는 경우

# %%
def min_max(row):
    data = row[rows]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %%
df.apply(min_max, axis=1)
# Out:
#                              min    max
# STNAME  CTYNAME
# Alabama Alabama            14226  59689
#         Autauga County       151    636
#         Baldwin County       517   2240
#         Barbour County        70    335
#         Bibb County           44    266
# ...                          ...    ...
# Wyoming Sweetwater County    167    657
#         Teton County          76    269
#         Uinta County          73    324
#         Washakie County       26    108
#         Weston County         26     93
#
# [3193 rows x 2 columns]

# %% [markdown]
# - row 를 반환하는 경우

# %%
def min_max(row):
    data = row[rows]
    row['max'] = np.max(data)
    row['min']  = np.min(data)
    return row

# %%
df.apply(min_max, axis=1)
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama                 14226       59689       59062       57938
#         Autauga County            151         636         615         574
#         Baldwin County            517        2187        2092        2160
#         Barbour County             70         335         300         283
#         Bibb County                44         266         245         259
# ...                               ...         ...         ...         ...
# Wyoming Sweetwater County         167         640         595         657
#         Teton County               76         259         230         261
#         Uinta County               73         324         311         316
#         Washakie County            26         108          90          95
#         Weston County              26          81          74          93
#
#                            BIRTHS2014  BIRTHS2015    max    min
# STNAME  CTYNAME
# Alabama Alabama                 58334       58305  59689  14226
#         Autauga County            623         600    636    151
#         Baldwin County           2186        2240   2240    517
#         Barbour County            260         269    335     70
#         Bibb County               247         253    266     44
# ...                               ...         ...    ...    ...
# Wyoming Sweetwater County         629         620    657    167
#         Teton County              249         269    269     76
#         Uinta County              316         316    324     73
#         Washakie County            96          90    108     26
#         Weston County              77          79     93     26
#
# [3193 rows x 8 columns]

# %% [markdown]
# ## Merging DataFrame

# %%
df = pd.DataFrame([{"name": "홍길동", "Item": "김치", "Cost": 22.50},
                   {"name": "김철수", "Item": "생선", "Cost": 2.50},
                   {"name": "이영희", "Item": "숫가락", "Cost": 5.00}],
                    index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#         name Item  Cost
# Store 1  홍길동   김치  22.5
# Store 1  김철수   생선   2.5
# Store 2  이영희  숫가락   5.0

# %% [markdown]
# - 새로운 column 추가

# %%
df['Date'] = ['December 1', 'January 1', 'mid-May']
df
# Out:
#         name Item  Cost        Date
# Store 1  홍길동   김치  22.5  December 1
# Store 1  김철수   생선   2.5   January 1
# Store 2  이영희  숫가락   5.0     mid-May

# %% [markdown]
# - broadcasting

# %%
df['Delivered'] = True
df
# Out:
#         name Item  Cost        Date  Delivered
# Store 1  홍길동   김치  22.5  December 1       True
# Store 1  김철수   생선   2.5   January 1       True
# Store 2  이영희  숫가락   5.0     mid-May       True

# %%
adf = df.reset_index()
adf
# Out:
#      index name Item  Cost        Date  Delivered
# 0  Store 1  홍길동   김치  22.5  December 1       True
# 1  Store 1  김철수   생선   2.5   January 1       True
# 2  Store 2  이영희  숫가락   5.0     mid-May       True

# %% [markdown]
# - 특정 column 의 값을 index 를 key 로 update

# %%
adf['Date'] = pd.Series({0: 'January 1', 2: 'mid-May'})
adf
# Out:
#      index name Item  Cost       Date  Delivered
# 0  Store 1  홍길동   김치  22.5  January 1       True
# 1  Store 1  김철수   생선   2.5        NaN       True
# 2  Store 2  이영희  숫가락   5.0    mid-May       True

# %% [markdown]
# # Merging and Concatenating

# %% [markdown]
# ## Concatenation
#
# Concatenation 은 DataFrame 들을 단순히 가져다 붙이는 것이다. 반드시 dimension 이 같아야 한다.

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                                'B': ['B0', 'B1', 'B2', 'B3'],
                                'C': ['C0', 'C1', 'C2', 'C3']},
                                 index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                                'B': ['B4', 'B5', 'B6', 'B7'],
                                'C': ['C4', 'C5', 'C6', 'C7']},
                                 index=[4, 5, 6, 7]) 

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                                'B': ['B8', 'B9', 'B10', 'B11'],
                                'C': ['C8', 'C9', 'C10', 'C11']},
                                index=[8, 9, 10, 11])

# %%
pd.concat([df1,df2,df3])  # default axis=0 이다. 즉, row 를 기준으로 concatenate 한다.
# Out:
#       A    B    C
# 0    A0   B0   C0
# 1    A1   B1   C1
# 2    A2   B2   C2
# 3    A3   B3   C3
# 4    A4   B4   C4
# 5    A5   B5   C5
# 6    A6   B6   C6
# 7    A7   B7   C7
# 8    A8   B8   C8
# 9    A9   B9   C9
# 10  A10  B10  C10
# 11  A11  B11  C11

# %%
pd.concat([df1,df2,df3],axis=1)  # axis = 1 로 지정하면 column 을 기준으로 concatenate 한다.
# Out:
#       A    B    C    A    B    C    A    B    C
# 0    A0   B0   C0  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN   A4   B4   C4  NaN  NaN  NaN
# 5   NaN  NaN  NaN   A5   B5   C5  NaN  NaN  NaN
# 6   NaN  NaN  NaN   A6   B6   C6  NaN  NaN  NaN
# 7   NaN  NaN  NaN   A7   B7   C7  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8
# 9   NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11

# %% [markdown]
# ## Merging
#
# Pandas 의 **merge** mothod는 SQL Table merge 와 유사한 기능을 제공한다.

# %% [markdown]
# ### DataFrame 간의 Join
#
# <img src="venDiagram.png" width=400>
# <p> Inner Join (Intersection) </p>
# <img src="innerJoin.png" width=300>

# %%
staff_df = pd.DataFrame([{"Name": '홍길동', "Role": '인사부장'},
                         {"Name": "김철수", "Role": '중간간부'},
                         {"Name": "이영희", "Role": "평가자"}])

staff_df = staff_df.set_index("Name")

staff_df
# Out:
#       Role
# Name
# 홍길동   인사부장
# 김철수   중간간부
# 이영희    평가자

# %%
student_df = pd.DataFrame([{"Name": '홍길동', "Major": 'Business'},
                           {"Name": "유재석", "Major": 'AI'},
                           {"Name": "이영희", "Major": "Engineering"}])

student_df = student_df.set_index("Name")
student_df
# Out:
#             Major
# Name
# 홍길동      Business
# 유재석            AI
# 이영희   Engineering

# %% [markdown]
# ### outer join

# %%
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#       Role        Major
# Name
# 김철수   중간간부          NaN
# 유재석    NaN           AI
# 이영희    평가자  Engineering
# 홍길동   인사부장     Business

# %% [markdown]
# ### inner join (default)

# %%
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#       Role        Major
# Name
# 홍길동   인사부장     Business
# 이영희    평가자  Engineering

# %% [markdown]
# ### left join $\rightarrow$ SQL 의 left outer join 과 유사

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#       Role        Major
# Name
# 홍길동   인사부장     Business
# 김철수   중간간부          NaN
# 이영희    평가자  Engineering

# %% [markdown]
# ### right join $\rightarrow$ SQL 의 right outer join 과 유사

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#       Role        Major
# Name
# 홍길동   인사부장     Business
# 유재석    NaN           AI
# 이영희    평가자  Engineering

# %% [markdown]
# ### index 가 단순 sequence 일 경우 join 할 column 지정

# %%
staff_df = staff_df.reset_index()
staff_df
# Out:
#   Name  Role
# 0  홍길동  인사부장
# 1  김철수  중간간부
# 2  이영희   평가자

# %%
student_df = student_df.reset_index()
student_df
# Out:
#   Name        Major
# 0  홍길동     Business
# 1  유재석           AI
# 2  이영희  Engineering

# %%
pd.merge(staff_df, student_df, left_on='Name', right_on='Name')
# Out:
#   Name  Role        Major
# 0  홍길동  인사부장     Business
# 1  이영희   평가자  Engineering

# %% [markdown]
# ## 중복된 column 명이 있을 경우 자동으로 suffix 부여

# %%
staff_df['Location'] = ['Korea', 'China', 'Europe']
staff_df
# Out:
#   Name  Role Location
# 0  홍길동  인사부장    Korea
# 1  김철수  중간간부    China
# 2  이영희   평가자   Europe

# %%
student_df['Location'] = ['Seoul', 'Pusan', 'Jeju']
student_df
# Out:
#   Name        Major Location
# 0  홍길동     Business    Seoul
# 1  유재석           AI    Pusan
# 2  이영희  Engineering     Jeju

# %% [markdown]
# ### left : `_x`, right: `_y`

# %%
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#   Name  Role Location_x        Major Location_y
# 0  홍길동  인사부장      Korea     Business      Seoul
# 1  김철수  중간간부      China          NaN        NaN
# 2  이영희   평가자     Europe  Engineering       Jeju

# %% [markdown]
# ## 연습 문제
#
# - 다음과 같은 두개의 DataFrame 을 생성하고 하나의 DataFrame 으로 join
#
# ### product DataFrame
#
# | productID | Price | Product |
# |:---:|:---:|:---:|
# | 4109| 5.0 | Sushi Roll |
# | 1412 | 0.5 | Egg |
# | 8931 | 1.5 | Bagel |
#
# ### invoice DataFrame
# <table>
#     <th></th>
#     <th>Customer</th>
#     <th>ProductId</th>
#     <th>Quantity</th>
#     <tr>
#     <td>0</td>
#      <td>ALL</td>
#      <td>4109</td>
#      <td>1</td>
#     </tr>
#     <tr>
#     <td>1</td>
#     <td>Eric</td>
#      <td>1412</td>
#      <td>12</td>
#      </tr>
#     <tr>
#      <td>2</td>
#     <td>Ande</td>
#      <td>8931</td>
#      <td>6</td>
#      </tr>
#     <tr>
#     <td>3</td>
#     <td>Sam</td>
#     <td>4109</td>
#     <td>2</td>
#     </tr>
# </table>

# %%
answer_df = pd.merge(# Code Here )

# %% [markdown]
# ```
#   Customer  ProductID  Quantity  Price     Product
# 0      Ali          4109         1          5.0    Sushi Roll
# 3      Sam       4109         2          5.0    Sushi Roll
# 1     Eric         1412        12         0.5         Egg
# 2     Ande       8931         6          1.5       Bagel
# ```

# %% [markdown]
# ## method chaining
#
# - readability를 향상 시키는 코딩 관습

# %%
df = pd.read_csv('data/winequality-red.csv', sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### without method chaining

# %%
tmp = df.where(df['quality'] == 3)
tmp = tmp.dropna()
tmp = tmp.reset_index()
tmp = tmp.rename(columns={'fixed acidity': 'acid', 'quality': 'target'})
tmp = tmp.loc[:, ['acid', 'target']]
tmp.head()
# Out:
#    acid  target
# 0  11.6     3.0
# 1  10.4     3.0
# 2   7.4     3.0
# 3  10.4     3.0
# 4   8.3     3.0

# %% [markdown]
# ### with method chaining
#
# - python은 `()`를 이용하면 여러 line 에 걸쳐 coding 가능

# %%
(df.where(df['quality'] == 3)
    .dropna()
    .reset_index()
    .rename(columns={'fixed acidity': 'acid', 'quality': 'target'})
    .loc[:, ['acid', 'target']]).head()
# Out:
#    acid  target
# 0  11.6     3.0
# 1  10.4     3.0
# 2   7.4     3.0
# 3  10.4     3.0
# 4   8.3     3.0

# %% [markdown]
# # Group by
#
# ### groupby 를 사용 않고 wine quaility 별 평균 fixed acidity 구하기

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
for quality in sorted(df['quality'].unique()):
    avg = np.mean(df.where(df['quality'] == quality).dropna()['fixed acidity'])
    print(f"quality {quality} 의 평균 fixed acidity 는 {avg:.2f}")
# Out:
# quality 3 의 평균 fixed acidity 는 8.36
# quality 4 의 평균 fixed acidity 는 7.78
# quality 5 의 평균 fixed acidity 는 8.17
# quality 6 의 평균 fixed acidity 는 8.35
# quality 7 의 평균 fixed acidity 는 8.87
# quality 8 의 평균 fixed acidity 는 8.57

# %% [markdown]
# ##  group by 를 사용
# ### without aggregate function

# %%
for group, frame in df.groupby('quality'):
    print(group)
    print(frame.shape)
# Out:
# 3
# (10, 12)
# 4
# (53, 12)
# 5
# (681, 12)
# 6
# (638, 12)
# 7
# (199, 12)
# 8
# (18, 12)

# %%
for group, frame in df.groupby('quality'):
    avg = np.mean(frame['fixed acidity'])
    print(f"quality {group} 의 평균 fixed acidity 는 {avg:.2f}")
# Out:
# quality 3 의 평균 fixed acidity 는 8.36
# quality 4 의 평균 fixed acidity 는 7.78
# quality 5 의 평균 fixed acidity 는 8.17
# quality 6 의 평균 fixed acidity 는 8.35
# quality 7 의 평균 fixed acidity 는 8.87
# quality 8 의 평균 fixed acidity 는 8.57

# %% [markdown]
# ### groupby + aggregate method 사용
# - agg : alias of aggretate

# %%
df.groupby('quality').agg({'fixed acidity': np.mean})
# Out:
#          fixed acidity
# quality
# 3             8.360000
# 4             7.779245
# 5             8.167254
# 6             8.347179
# 7             8.872362
# 8             8.566667

# %% [markdown]
# ## Scales (척도)
#
# - 비율 척도 (ratio scale): 절대 영점이 있는 등간 척도. 0이 절대적인 기준이 되며 두 척도 사이에 비율이 존재. 우리가 사용하는 대부분의 척도
# (예. 거리, 무게, 시간 등)
#
# - 등간 척도(interval scale): 척도간의 간격이 일정. 0이 아무런 기준을 갖지 않음.(예. 온도)
#
# - 순위 척도(ordinal scale) : 말 그대로 순위를 나타내는 척도 (예. 성적)
#
# - 명목 척도 (nominal scale): 말 그대로 이름뿐인 척도. Categorical data. 순서 없음. (예. 남성, 여성, 동물 종류)

# %%
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D'],
            index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor'],
            columns=['Grades'])
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor           D

# %% [markdown]
# ### 순서가 없는 Category 변수 (명목 척도)
# - Nominal Variable (명목 변수) 라고도 부르며 Pandas 에서는 `category` data type으로 지원된다.

# %%
df.Grades.head(2)
# Out:
# excellent    A+
# excellent     A
# Name: Grades, dtype: object

# %%
df['Grades'] = df['Grades'].astype('category')
df.Grades.head(2)
# Out:
# excellent    A+
# excellent     A
# Name: Grades, dtype: category
# Categories (10, object): [A, A+, A-, B, ..., C, C+, C-, D]

# %% [markdown]
# ### 순서가 있는 Category 변수 (순위 척도)
#
# - data type 변환 방법
#
#     - Grades column 을 순서가 있는 category column 으로 변환.
#     - number 로 encoding 않아도 data 자체에서 category 의 순서를 기억하도록 Pandas 가 지원

# %%
df['Grades'] = pd.Categorical(df['Grades'], 
                    categories=['D', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'], 
                    ordered=True)
df.Grades.head(2)
# Out:
# excellent    A+
# excellent     A
# Name: Grades, dtype: category
# Categories (10, object): [D < C- < C < C+ ... B+ < A- < A < A+]

# %%
df.Grades > 'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# Name: Grades, dtype: bool

# %% [markdown]
# ### binning
# - 연속된 숫자를 구간화 (등간 척도)
#
# - pandas 는 `bin` method로 binning 지원

# %%
s = pd.Series([168, 180, 174, 190, 170, 185, 179, 181, 175, 160, 182, 177, 180, 171])

pd.cut(s, 3)
# Out:
# 0     (159.97, 170.0]
# 1      (170.0, 180.0]
# 2      (170.0, 180.0]
# 3      (180.0, 190.0]
# 4     (159.97, 170.0]
# 5      (180.0, 190.0]
# 6      (170.0, 180.0]
# 7      (180.0, 190.0]
# 8      (170.0, 180.0]
# 9     (159.97, 170.0]
# 10     (180.0, 190.0]
# 11     (170.0, 180.0]
# 12     (170.0, 180.0]
# 13     (170.0, 180.0]
# dtype: category
# Categories (3, interval[float64]): [(159.97, 170.0] < (170.0, 180.0] < (180.0, 190.0]]

# %% [markdown]
# #### 3 구간으로 구분
#
# - 구간명 부여

# %%
s1 = pd.cut(s, 3, labels=['Small', 'Medium', 'Large'])
s1.head(2)
# Out:
# 0     Small
# 1    Medium
# dtype: category
# Categories (3, object): [Small < Medium < Large]

# %%
s1.cat.categories
# Out:
# Index(['Small', 'Medium', 'Large'], dtype='object')

# %%
s1.cat.remove_categories('Small')
# Out:
# 0        NaN
# 1     Medium
# 2     Medium
# 3      Large
# 4        NaN
# 5      Large
# 6     Medium
# 7      Large
# 8     Medium
# 9        NaN
# 10     Large
# 11    Medium
# 12    Medium
# 13    Medium
# dtype: category
# Categories (2, object): [Medium < Large]

# %%
s1 = s1.cat.add_categories(['A', 'B'])
s1
# Out:
# 0      Small
# 1     Medium
# 2     Medium
# 3      Large
# 4      Small
# 5      Large
# 6     Medium
# 7      Large
# 8     Medium
# 9      Small
# 10     Large
# 11    Medium
# 12    Medium
# 13    Medium
# dtype: category
# Categories (5, object): [Small < Medium < Large < A < B]

# %%
s1.cat.reorder_categories(['A', 'B', 'Small', 'Medium', 'Large'])
# Out:
# 0      Small
# 1     Medium
# 2     Medium
# 3      Large
# 4      Small
# 5      Large
# 6     Medium
# 7      Large
# 8     Medium
# 9      Small
# 10     Large
# 11    Medium
# 12    Medium
# 13    Medium
# dtype: category
# Categories (5, object): [A < B < Small < Medium < Large]

# %% [markdown]
# ### category 변수 연습

# %%
df = pd.read_csv("data/winequality-red.csv", sep=";")
df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5

# %%
df['quality'].head(2)
# Out:
# 0    5
# 1    5
# Name: quality, dtype: int64

# %%
# quality 를 category 변수로 변환
df['quality'] = df['quality'].astype('category')
df['quality'].head(2)
# Out:
# 0    5
# 1    5
# Name: quality, dtype: category
# Categories (6, int64): [3, 4, 5, 6, 7, 8]

# %%
# fixed acidity 를 구간화
df['fixed acidity'] = pd.cut(df['fixed acidity'], 3, labels=['high', 'medium', 'low'])
df.head(2)
# Out:
#   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          high              0.70          0.0             1.9      0.076
# 1          high              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol quality
# 0      9.4       5
# 1      9.8       5

# %%
df['fixed acidity'].cat.categories
# Out:
# Index(['high', 'medium', 'low'], dtype='object')

# %% [markdown]
# ## Pivot Tabels
#
# - 여러 데이터 중에서 자신이 원하는 데이터만을 가지고 원하는 행과 열에 데이터를 배치하여 새로운 보고서를 만드는 기능
#
# - SQL 의 query 기능과 유사

# %%
df = pd.read_csv("data/cars.csv")
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# 0              2.4               2.1       0     NaN   100         7
# 1              2.6               2.4       0     NaN   117         7
# 2              2.4               2.2       0     NaN   122         4
# 3              2.4               2.1       0     NaN   100         7
# 4              2.6               2.4       0     NaN   117         7

# %% [markdown]
# ### pivot table 작성 1
# - 전기차 연비 data 에서 연도, 제작사 (`YEAR`, `Make`) 별로 평균 배터리용량 `(kw)` 을 보여주는 pivot table 생성
#
# - 연도를 index 로 하고, 제작사를 column 에 배치
#
# - pivot table 의 value 는 해당연도 제작사 배터리 용량의 평균값 표시

# %%
df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=np.mean)
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %% [markdown]
# ### pivot table 작성 2
#
# - 위와 동일한 방법으로 평균과 최소량을 동시에 보여주는 pivot table 생성

# %%
df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=[np.mean, np.min])
# Out:
#        mean                                                              amin  \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA    BMW
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN    NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000    NaN
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333    NaN
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667  125.0
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000  125.0
#
#
# Make CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART  TESLA
# YEAR
# 2012       NaN    NaN   NaN       49.0   80.0   NaN    NaN
# 2013       NaN  107.0   NaN       49.0   80.0  35.0  270.0
# 2014     104.0  107.0   NaN       49.0   80.0  35.0  225.0
# 2015     104.0  107.0  81.0       49.0   80.0  35.0  280.0
# 2016     104.0  107.0  81.0       49.0   80.0  35.0  283.0

# %% [markdown]
# - aggfunc 별 subtotal 추가
#
# - margin = True

# %%
df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=[np.mean, np.min], margins=True)
# Out:
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
# All   125.0     104.0  107.0  81.0       49.0   80.0  35.0  345.478261
#
#                    amin                                                        \
# Make         All    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART  TESLA
# YEAR
# 2012   64.500000    NaN       NaN    NaN   NaN       49.0   80.0   NaN    NaN
# 2013  158.444444    NaN       NaN  107.0   NaN       49.0   80.0  35.0  270.0
# 2014  135.000000    NaN     104.0  107.0   NaN       49.0   80.0  35.0  225.0
# 2015  181.428571  125.0     104.0  107.0  81.0       49.0   80.0  35.0  280.0
# 2016  252.263158  125.0     104.0  107.0  81.0       49.0   80.0  35.0  283.0
# All   190.622642  125.0     104.0  107.0  81.0       49.0   80.0  35.0  225.0
#
#
# Make All
# YEAR
# 2012  49
# 2013  35
# 2014  35
# 2015  35
# 2016  35
# All   35

# %% [markdown]
# ## 연습 문제
#
# - 위의 cars.csv 파일의 column 명이 너무 길므로 column 명 중 `(kW)` 를 `kw` 로,  `CITY (kWh/100 km)` 을 `city-km` 으로 변경
#
# - groupby 함수를 사용하여,  연도별 평균 배터리 용량(`kw`) 표시 (`Make` 무시)
#
# - 연도, 제작사별로 평균 `city-km`을 보여주는 pivot table 작성

# %%
# column 명 변경
df = df.rename(%code here%)
df.head()

# %%
# groupby code here

# %%
# 연도별 평균 배터리 용량 code here

# %% [markdown]
# # Date data 처리 기능
#
# ### Timestamp
#
# - Python 의 datetime 과 대부분의 경우 호환
#
# - DatetimeIndex 로 사용

# %%
pd.Timestamp('10/12/2021 10:30PM')
# Out:
# Timestamp('2021-10-12 22:30:00')

# %%
pd.Timestamp('2021-10-12 10:30PM')
# Out:
# Timestamp('2021-10-12 22:30:00')

# %%
import datetime

datetime.datetime(2020, 10, 12, 22, 30)
# Out:
# datetime.datetime(2020, 10, 12, 22, 30)

# %% [markdown]
# ### DatetimeIndex

# %%
ts1 = pd.Series(list('abc'), 
                   index=[pd.Timestamp('2020-09-01'), 
                              pd.Timestamp('2020-09-02'), 
                              pd.Timestamp('2020-09-03')])
ts1
# Out:
# 2020-09-01    a
# 2020-09-02    b
# 2020-09-03    c
# dtype: object

# %%
type(ts1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Datetime format 으로 convert
#
# - 다양한 현태의 날자 표현을 모두 `pd.to_datetime` method를 이용하여 DatetimeIndex로 변환

# %%
d1 = ['2 June 2013', 'Aug 29, 2020', '2018-06-30', '7/12/2017']

ts2 = pd.DataFrame(np.random.randint(10, 100, (4, 2)), index=d1, columns=list('ab'))
ts2
# Out:
#                a   b
# 2 June 2013   47  65
# Aug 29, 2020  93  83
# 2018-06-30    99  60
# 7/12/2017     61  53

# %%
ts2.index = pd.to_datetime(ts2.index)
ts2
# Out:
#              a   b
# 2013-06-02  47  65
# 2020-08-29  93  83
# 2018-06-30  99  60
# 2017-07-12  61  53

# %%
ts2.plot()

# %% [markdown]
# ### Timedelta
#
# - difference of time

# %%
pd.Timestamp('2020-10-02') - pd.Timestamp('2020-09-30')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('2020-10-02 8:10AM') + pd.Timedelta('30d 10h')
# Out:
# Timestamp('2020-11-01 18:10:00')
